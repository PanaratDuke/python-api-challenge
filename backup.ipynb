# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# %%
# Import API key
from api_keys import weather_api_key

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lat_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# %%
# # Build query URL and request results
# url = "http://api.openweathermap.org/data/2.5/weather?"#units=Imperial&" lat=35&lon=139
# units = "Imperial"
# query_url = f"{url}appid={weather_api_key}&units={units}&q="

# # Print to check URL is valid
# city_url

# %% [markdown]
# # Use random function to generate random number

# %%
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=10)
lngs = np.random.uniform(low=-180.000, high=180.000, size=10)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
         cities.append(city)
            
cities
# Out:
# ['jamestown',
#  'butaritari',
#  'hermanus',
#  'weihai',
#  'port elizabeth',
#  'mantua',
#  'albany',
#  'ostrovnoy',
#  'vakhrushi',
#  'ponta do sol',
#  'punta arenas',
#  'rikitea',
#  'port alfred',
#  'yellowknife',
#  'mataura',
#  'vaini',
#  'vaitupu',
#  'leshukonskoye',
#  'sorvag',
#  'ushuaia',
#  'cayenne',
#  'vila do maio',
#  'bengkulu',
#  'sentyabrskiy',
#  'sola',
#  'sabha',
#  'atuona',
#  'muravlenko',
#  'bredasdorp',
#  'bambous virieux',
#  'hobart',
#  'tasiilaq',
#  'cape town',
#  'umzimvubu',
#  'oakdale',
#  'kondinskoye',
#  'nikolskoye',
#  'airai',
#  'hilo',
#  'klaksvik',
#  'coquimbo',
#  'aklavik',
#  'taolanaro',
#  'hervey bay',
#  'presidencia roque saenz pena',
#  'busselton',
#  'malwan',
#  'saleaula',
#  'clyde river',
#  'yabrud',
#  'saldanha',
#  'mar del plata',
#  'puerto ayora',
#  'saint-philippe',
#  'isangel',
#  'qaanaaq',
#  'belushya guba',
#  'ambilobe',
#  'nagato',
#  'poum',
#  'barrow',
#  'constitucion',
# ...

# %% [raw]
# # north_lats = np.random.uniform(low=0, high=90.000, size=3)
# # north_lngs = np.random.uniform(low=-180.000, high=180.000, size=3)
#
# # south_lats = np.random.uniform(low=-90.000, high=0, size=3)
# # south_lngs = np.random.uniform(low=-180.000, high=180.000, size=3)
#
#
# # Format into one dataframe with lat and long in one row
#
# # north_lat_lngs = zip(north_lats, north_lngs)
# # south_lat_lngs = zip(south_lats, south_lngs)
#
#
# # print_lat_lngs = list(lat_lngs)
# # print_north_lat_lngs = list(north_lat_lngs)
# # print_south_lat_lngs = list(south_lat_lngs)
#
# # print(f'{print_lat_lngs}')
# # print(f'{print_north_lat_lngs}')
# # print(f'{print_south_lat_lngs}')

# %% [markdown]
# # Create query url and request data from website

# %% [raw]
# # Build query URL and request result
# # responses = [];
#
# # for lat_lng in lat_lngs:
# #     query_url = f"lat={lat_lng[0]}&lon={lat_lng[1]}&appid={weather_api_key}"
# #     cities_weather = requests.get(url+query_url).json()
#
# #     # Request will be pause for 2 seconds
# #     time.sleep(2)
# #     responses.append(cities_weather)
# #     # Using json to print with readabel format
# #     print("All")
# #     print(json.dumps(responses, indent=2))
#
# # for north_lat_lng in print_north_lat_lngs:
# #     north_q_url = f"lat={north_lat_lng[0]}&lon={north_lat_lng[1]}&appid={weather_api_key}"
# #     cities_north_weather = requests.get(url+query_url).json()
# #     time.sleep(2)
# #     north_responses.append(cities_north_weather)
# # #     print('\nNorth')
# # #     print(json.dumps(north_responses, indent=2))
#
# # for south_lat_lng in print_south_lat_lngs:
# #     south_q_url = f"lat={south_lat_lng[0]}&lon={south_lat_lng[1]}&appid={weather_api_key}"
# #     cities_south_weather = requests.get(url+query_url).json()
# #     time.sleep(2)
# #     south_responses.append(cities_south_weather)
# #     print('\nSouth')
# #     print(json.dumps(south_responses, indent=2))

# %% [markdown]
# # Get cities name from citipy

# %%
# set up lists to hold reponse info
lat = []
temp = []
humid = []
cloud = []
wind_speed = []


# Loop through the list of cities and perform a request for data on each
# var city_response is holding data that request from the website as dictionary
for city in cities:
    query_url+city
    response = requests.get(query_url + city).json()
    response
    
#     # Refer to data value in each request
    lat.append(response['coord']['lat'])
    lat
    temp.append(city_response['main']['temp'])
    humid.append(city_response['main']['humidity'])
    cloud.append(city_response['clouds']['all'])
    wind_speed.append(city_response['wind']['speed'])
    
# Check all append value in all the lists
print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
print(f"The humidity information received is: {humid}")
print(f"The cloudiness information received is: {cloud}")
print(f"The wind spped information received is: {wind_speed}")

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"#units=Imperial&" lat=35&lon=139
units = "Imperial"

# %%
lat = []
city_name = []

query_url = f"{url}appid={weather_api_key}&units={units}&q="

query_url
# for city in cities:
#     response = requests.get(query_url + city).json
# #     lat.append(response['coord']['lat'])
#     city_name.append(city)
#     print(city)
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=368264d9d6377ab42b4204478a7686c9&units=Imperial&q='

# %% [markdown]
# # Create Dataframe to store requests from those lists

# %%
# create a data frame from cities, lat, and temp
# weather_dict = {
#     "city": cities,
#     "lat": lat,
#     "temp": temp,
#     "humid":humid,
#     "cloudiness":cloud,
#     "wind_speed":wind_speed
# }
# weather_data = pd.DataFrame(weather_dict)
# weather_data.head()

# %% [markdown]
# # Create scatter plots

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature(03/14/20)")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["humid"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity(03/14/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (03/14/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInWorldCities.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. wind_speed (03/14/20)")
plt.ylabel("wind_speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WinSpeedInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# # Norther Hemisphere

# %%
# Northern Heisphere (Latitude > = 0)
lat_range = (0, 90)
lat_range = (-180, 180)

# %% [markdown]
# # Use random function to generate random number

# %%
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=0, high=90.000, size=3)
lngs = np.random.uniform(low=-180.000, high=180.000, size=3)

# Format into one dataframe with lat and long in one row
lat_lngs = zip(lats, lngs)
# lat_lngs
print_lat_lngs = list(lat_lngs) 
# print(f'{print_lat_lngs}')

# %% [markdown]
# # Create query url and request data from website

# %%
# Build query URL and request result
responses = [];

for lat_lng in print_lat_lngs:
    query_url = f"lat={lat_lng[0]}&lon={lat_lng[1]}&appid={weather_api_key}"
    cities_weather = requests.get(url+query_url).json()

    # Request will be pause for 2 seconds   
    time.sleep(2)
    responses.append(cities_weather)
    # Using json to print with readabel format
    #print(json.dumps(responses, indent=2))

# %% [markdown]
# # Southern Hemisphere

# %%
# Southern Hemisphere (Latitude <  0)
lat_range = (-90, 0)
lat_range = (-180, 180)

# %% [markdown]
# # Use random function to generate random number

# %%
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=0, size=3)
lngs = np.random.uniform(low=-180.000, high=180.000, size=3)

# Format into one dataframe with lat and long in one row
lat_lngs = zip(lats, lngs)
# lat_lngs
print_lat_lngs = list(lat_lngs) 
print(f'{print_lat_lngs}')
