# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats
from scipy.stats import linregress

# %%
# Import API key
from api_key import weather_api_key

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lat_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# Create a set of random lat and lng combinations
lat_lngs = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
cities = []

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
         cities.append(city)            
# cities

# %% [markdown]
# # Perform API Calls

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
# query_url

# %%
lat = []
lon = []
max_temp = []
humidity = []
cloudiness = []

wind_speed = []
date = []
country = []
city_name = []

not_located = []
except_set = 1

print('Beginning Data Rerieval')
print('-----------------------')

for index, city in enumerate(cities, start=1):
    try:
        
        response = requests.get(query_url + city).json()
        # Request will be pause for 2 seconds   
        time.sleep(2)
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        
        wind_speed.append(response["wind"]["speed"])
        date.append(response["dt"])
        country.append(response["sys"]["country"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        city_name.append(city)
        print(f'Processing Record {index} of Set {except_set} | {city}')
        
    except:
        
        not_located.append(city)
        print(f"city({city}) not found")
        except_set+= 1
print('-----------------------')
print('Data Retrieval Complete')
print('-----------------------')
# Out:
# Beginning Data Rerieval
# -----------------------
# Processing Record 1 of Set 1 | san patricio
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | belaya gora
# Processing Record 5 of Set 1 | dingle
# Processing Record 6 of Set 1 | xingyi
# Processing Record 7 of Set 1 | chuy
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | great yarmouth
# Processing Record 12 of Set 1 | biak
# Processing Record 13 of Set 1 | benfleet
# Processing Record 14 of Set 1 | shahr-e kord
# Processing Record 15 of Set 1 | nurota
# city(tsihombe) not found
# Processing Record 17 of Set 2 | deputatskiy
# Processing Record 18 of Set 2 | leh
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | aklavik
# Processing Record 21 of Set 2 | ekuvukeni
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | batemans bay
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | ushuaia
# city(vaitupu) not found
# Processing Record 28 of Set 3 | esperance
# city(barentsburg) not found
# Processing Record 30 of Set 4 | arraial do cabo
# Processing Record 31 of Set 4 | veraval
# Processing Record 32 of Set 4 | victoria
# Processing Record 33 of Set 4 | barrow
# Processing Record 34 of Set 4 | luderitz
# Processing Record 35 of Set 4 | hobart
# city(grand river south east) not found
# Processing Record 37 of Set 5 | yellowknife
# Processing Record 38 of Set 5 | bluff
# Processing Record 39 of Set 5 | hartselle
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | bethel
# Processing Record 42 of Set 5 | cape town
# Processing Record 43 of Set 5 | bassila
# Processing Record 44 of Set 5 | lasa
# Processing Record 45 of Set 5 | vardo
# Processing Record 46 of Set 5 | port alfred
# Processing Record 47 of Set 5 | roald
# Processing Record 48 of Set 5 | busselton
# Processing Record 49 of Set 5 | punta arenas
# Processing Record 50 of Set 5 | lompoc
# Processing Record 51 of Set 5 | newark
# Processing Record 52 of Set 5 | moron
# city(amderma) not found
# Processing Record 54 of Set 6 | hasaki
# Processing Record 55 of Set 6 | qaqortoq
# Processing Record 56 of Set 6 | nueva guinea
# Processing Record 57 of Set 6 | carnarvon
# Processing Record 58 of Set 6 | saint-philippe
# Processing Record 59 of Set 6 | fortuna
# city(attawapiskat) not found
# Processing Record 61 of Set 7 | hilo
# Processing Record 62 of Set 7 | kapaa
# Processing Record 63 of Set 7 | puerto ayacucho
# Processing Record 64 of Set 7 | nikolskoye
# Processing Record 65 of Set 7 | dikson
# Processing Record 66 of Set 7 | touros
# Processing Record 67 of Set 7 | nome
# Processing Record 68 of Set 7 | sydney
# Processing Record 69 of Set 7 | hamilton
# Processing Record 70 of Set 7 | sohbatpur
# Processing Record 71 of Set 7 | vaini
# Processing Record 72 of Set 7 | fairbanks
# Processing Record 73 of Set 7 | bredasdorp
# Processing Record 74 of Set 7 | mar del plata
# Processing Record 75 of Set 7 | tiksi
# Processing Record 76 of Set 7 | olga
# Processing Record 77 of Set 7 | namatanai
# Processing Record 78 of Set 7 | tasiilaq
# city(nizhneyansk) not found
# Processing Record 80 of Set 8 | acarau
# Processing Record 81 of Set 8 | ponta do sol
# Processing Record 82 of Set 8 | port elizabeth
# Processing Record 83 of Set 8 | mahebourg
# city(toliary) not found
# Processing Record 85 of Set 9 | cabo san lucas
# Processing Record 86 of Set 9 | kaitangata
# Processing Record 87 of Set 9 | thompson
# Processing Record 88 of Set 9 | ribeira grande
# Processing Record 89 of Set 9 | port hedland
# Processing Record 90 of Set 9 | cayenne
# Processing Record 91 of Set 9 | cherskiy
# Processing Record 92 of Set 9 | beringovskiy
# Processing Record 93 of Set 9 | pevek
# Processing Record 94 of Set 9 | bengkulu
# Processing Record 95 of Set 9 | new norfolk
# Processing Record 96 of Set 9 | mishkino
# Processing Record 97 of Set 9 | presidente epitacio
# Processing Record 98 of Set 9 | yenagoa
# Processing Record 99 of Set 9 | tuatapere
# Processing Record 100 of Set 9 | jalu
# Processing Record 101 of Set 9 | luban
# Processing Record 102 of Set 9 | pringsewu
# Processing Record 103 of Set 9 | gberia fotombu
# Processing Record 104 of Set 9 | castro
# Processing Record 105 of Set 9 | puerto ayora
# Processing Record 106 of Set 9 | piuma
# Processing Record 107 of Set 9 | bambous virieux
# Processing Record 108 of Set 9 | oktyabrskoye
# Processing Record 109 of Set 9 | udachnyy
# Processing Record 110 of Set 9 | marsh harbour
# Processing Record 111 of Set 9 | pangnirtung
# Processing Record 112 of Set 9 | trairi
# Processing Record 113 of Set 9 | poplar bluff
# Processing Record 114 of Set 9 | albany
# Processing Record 115 of Set 9 | bandarbeyla
# Processing Record 116 of Set 9 | east london
# Processing Record 117 of Set 9 | okha
# Processing Record 118 of Set 9 | angoche
# Processing Record 119 of Set 9 | tuktoyaktuk
# Processing Record 120 of Set 9 | alofi
# Processing Record 121 of Set 9 | codrington
# Processing Record 122 of Set 9 | medicine hat
# city(taolanaro) not found
# Processing Record 124 of Set 10 | serta
# Processing Record 125 of Set 10 | bilma
# Processing Record 126 of Set 10 | magaria
# Processing Record 127 of Set 10 | jamestown
# Processing Record 128 of Set 10 | hami
# Processing Record 129 of Set 10 | karpathos
# city(rolim de moura) not found
# Processing Record 131 of Set 11 | samoded
# Processing Record 132 of Set 11 | souillac
# city(illoqqortoormiut) not found
# Processing Record 134 of Set 12 | kavaratti
# Processing Record 135 of Set 12 | beloha
# Processing Record 136 of Set 12 | hermanus
# Processing Record 137 of Set 12 | camabatela
# Processing Record 138 of Set 12 | rio gallegos
# Processing Record 139 of Set 12 | simplicio mendes
# Processing Record 140 of Set 12 | togur
# Processing Record 141 of Set 12 | brazzaville
# city(ngukurr) not found
# Processing Record 143 of Set 13 | portland
# Processing Record 144 of Set 13 | maniitsoq
# Processing Record 145 of Set 13 | saint-georges
# Processing Record 146 of Set 13 | porto-vecchio
# Processing Record 147 of Set 13 | upington
# Processing Record 148 of Set 13 | lae
# Processing Record 149 of Set 13 | jamsa
# Processing Record 150 of Set 13 | leningradskiy
# Processing Record 151 of Set 13 | bereda
# Processing Record 152 of Set 13 | iqaluit
# Processing Record 153 of Set 13 | sosnovo-ozerskoye
# Processing Record 154 of Set 13 | teguise
# Processing Record 155 of Set 13 | abeche
# Processing Record 156 of Set 13 | otaru
# Processing Record 157 of Set 13 | lazaro cardenas
# Processing Record 158 of Set 13 | baykit
# Processing Record 159 of Set 13 | pandan
# Processing Record 160 of Set 13 | san juan
# Processing Record 161 of Set 13 | mahon
# Processing Record 162 of Set 13 | georgetown
# Processing Record 163 of Set 13 | tomatlan
# Processing Record 164 of Set 13 | comodoro rivadavia
# city(mys shmidta) not found
# Processing Record 166 of Set 14 | camocim
# Processing Record 167 of Set 14 | mae hong son
# city(haademeeste) not found
# Processing Record 169 of Set 15 | vilyuysk
# Processing Record 170 of Set 15 | sao felix do xingu
# Processing Record 171 of Set 15 | hirado
# Processing Record 172 of Set 15 | inirida
# Processing Record 173 of Set 15 | nanortalik
# Processing Record 174 of Set 15 | meaford
# city(skovde) not found
# Processing Record 176 of Set 16 | tilichiki
# Processing Record 177 of Set 16 | guerrero negro
# Processing Record 178 of Set 16 | ruteng
# Processing Record 179 of Set 16 | huanren
# Processing Record 180 of Set 16 | tual
# Processing Record 181 of Set 16 | quesnel
# Processing Record 182 of Set 16 | ventspils
# Processing Record 183 of Set 16 | butaritari
# Processing Record 184 of Set 16 | la primavera
# city(sentyabrskiy) not found
# Processing Record 186 of Set 17 | mount gambier
# Processing Record 187 of Set 17 | fort frances
# Processing Record 188 of Set 17 | mittagong
# Processing Record 189 of Set 17 | tibanban
# Processing Record 190 of Set 17 | nizwa
# Processing Record 191 of Set 17 | porto novo
# Processing Record 192 of Set 17 | rocha
# Processing Record 193 of Set 17 | nampa
# Processing Record 194 of Set 17 | wewak
# Processing Record 195 of Set 17 | zhigansk
# Processing Record 196 of Set 17 | najran
# Processing Record 197 of Set 17 | peterhead
# Processing Record 198 of Set 17 | jacksonville
# Processing Record 199 of Set 17 | kidal
# Processing Record 200 of Set 17 | baft
# city(haibowan) not found
# Processing Record 202 of Set 18 | kingston
# Processing Record 203 of Set 18 | west wendover
# Processing Record 204 of Set 18 | regina
# Processing Record 205 of Set 18 | namibe
# Processing Record 206 of Set 18 | ornskoldsvik
# Processing Record 207 of Set 18 | pietarsaari
# Processing Record 208 of Set 18 | kolpashevo
# Processing Record 209 of Set 18 | dossor
# Processing Record 210 of Set 18 | makakilo city
# Processing Record 211 of Set 18 | severo-kurilsk
# Processing Record 212 of Set 18 | xining
# Processing Record 213 of Set 18 | konevo
# Processing Record 214 of Set 18 | kavieng
# Processing Record 215 of Set 18 | meulaboh
# Processing Record 216 of Set 18 | aksu
# Processing Record 217 of Set 18 | parrita
# city(meyungs) not found
# Processing Record 219 of Set 19 | jega
# Processing Record 220 of Set 19 | waw
# Processing Record 221 of Set 19 | shigony
# city(samusu) not found
# Processing Record 223 of Set 20 | chebarkul
# city(nguiu) not found
# Processing Record 225 of Set 21 | lavrentiya
# Processing Record 226 of Set 21 | banda aceh
# Processing Record 227 of Set 21 | rawson
# Processing Record 228 of Set 21 | nago
# Processing Record 229 of Set 21 | klaksvik
# Processing Record 230 of Set 21 | kemin
# Processing Record 231 of Set 21 | grafton
# Processing Record 232 of Set 21 | narsaq
# Processing Record 233 of Set 21 | wolnzach
# Processing Record 234 of Set 21 | palmer
# Processing Record 235 of Set 21 | kruisfontein
# city(palabuhanratu) not found
# Processing Record 237 of Set 22 | soyo
# Processing Record 238 of Set 22 | norman wells
# Processing Record 239 of Set 22 | srednekolymsk
# Processing Record 240 of Set 22 | capao bonito
# Processing Record 241 of Set 22 | pathein
# Processing Record 242 of Set 22 | saldanha
# Processing Record 243 of Set 22 | tiarei
# Processing Record 244 of Set 22 | airai
# Processing Record 245 of Set 22 | neuquen
# Processing Record 246 of Set 22 | formosa
# Processing Record 247 of Set 22 | ola
# Processing Record 248 of Set 22 | gravdal
# Processing Record 249 of Set 22 | geraldton
# Processing Record 250 of Set 22 | shebalino
# Processing Record 251 of Set 22 | lagoa
# Processing Record 252 of Set 22 | chokurdakh
# Processing Record 253 of Set 22 | flinders
# city(chagda) not found
# city(saleaula) not found
# Processing Record 256 of Set 24 | ucluelet
# Processing Record 257 of Set 24 | karratha
# city(kytlym) not found
# Processing Record 259 of Set 25 | paita
# Processing Record 260 of Set 25 | chokwe
# Processing Record 261 of Set 25 | ciudad bolivar
# Processing Record 262 of Set 25 | salinopolis
# Processing Record 263 of Set 25 | shuangcheng
# Processing Record 264 of Set 25 | morehead
# Processing Record 265 of Set 25 | iquique
# Processing Record 266 of Set 25 | saint george
# Processing Record 267 of Set 25 | kloulklubed
# Processing Record 268 of Set 25 | tadine
# Processing Record 269 of Set 25 | ancud
# Processing Record 270 of Set 25 | viedma
# Processing Record 271 of Set 25 | hawkesbury
# Processing Record 272 of Set 25 | yasothon
# Processing Record 273 of Set 25 | torbay
# Processing Record 274 of Set 25 | san ignacio
# Processing Record 275 of Set 25 | yerbogachen
# Processing Record 276 of Set 25 | eaglesfield
# Processing Record 277 of Set 25 | batagay
# Processing Record 278 of Set 25 | spornoye
# Processing Record 279 of Set 25 | sartana
# Processing Record 280 of Set 25 | faya
# Processing Record 281 of Set 25 | takanabe
# Processing Record 282 of Set 25 | kharan
# Processing Record 283 of Set 25 | ostrovnoy
# Processing Record 284 of Set 25 | katsuura
# Processing Record 285 of Set 25 | isangel
# Processing Record 286 of Set 25 | sandwick
# Processing Record 287 of Set 25 | turan
# Processing Record 288 of Set 25 | conceicao do araguaia
# Processing Record 289 of Set 25 | narrabri
# Processing Record 290 of Set 25 | teguldet
# Processing Record 291 of Set 25 | doume
# city(belushya guba) not found
# Processing Record 293 of Set 26 | kapustin yar
# Processing Record 294 of Set 26 | abu kamal
# Processing Record 295 of Set 26 | yulara
# Processing Record 296 of Set 26 | inta
# Processing Record 297 of Set 26 | khabary
# Processing Record 298 of Set 26 | haapiti
# Processing Record 299 of Set 26 | rio grande
# Processing Record 300 of Set 26 | lata
# Processing Record 301 of Set 26 | anadyr
# Processing Record 302 of Set 26 | tambopata
# Processing Record 303 of Set 26 | mareeba
# Processing Record 304 of Set 26 | lang son
# Processing Record 305 of Set 26 | metro
# Processing Record 306 of Set 26 | ariquemes
# Processing Record 307 of Set 26 | balabac
# Processing Record 308 of Set 26 | carutapera
# Processing Record 309 of Set 26 | kahului
# Processing Record 310 of Set 26 | pisco
# Processing Record 311 of Set 26 | mahina
# Processing Record 312 of Set 26 | yelizovo
# Processing Record 313 of Set 26 | sao filipe
# Processing Record 314 of Set 26 | omsukchan
# Processing Record 315 of Set 26 | salym
# Processing Record 316 of Set 26 | longyearbyen
# city(bolungarvik) not found
# Processing Record 318 of Set 27 | vijapur
# Processing Record 319 of Set 27 | shingu
# Processing Record 320 of Set 27 | kitaibaraki
# Processing Record 321 of Set 27 | coquimbo
# Processing Record 322 of Set 27 | gasa
# Processing Record 323 of Set 27 | nanakuli
# Processing Record 324 of Set 27 | aleksandrovskiy zavod
# Processing Record 325 of Set 27 | ilulissat
# Processing Record 326 of Set 27 | kaeo
# Processing Record 327 of Set 27 | santa maria
# city(katsiveli) not found
# city(louisbourg) not found
# Processing Record 330 of Set 29 | coihaique
# Processing Record 331 of Set 29 | mananjary
# Processing Record 332 of Set 29 | novaya zaimka
# Processing Record 333 of Set 29 | la ronge
# Processing Record 334 of Set 29 | chipinge
# Processing Record 335 of Set 29 | quetta
# Processing Record 336 of Set 29 | ponca city
# Processing Record 337 of Set 29 | tutoia
# Processing Record 338 of Set 29 | skibbereen
# Processing Record 339 of Set 29 | port augusta
# Processing Record 340 of Set 29 | dwarka
# Processing Record 341 of Set 29 | aktau
# Processing Record 342 of Set 29 | bulgan
# city(kamenskoye) not found
# Processing Record 344 of Set 30 | kita
# Processing Record 345 of Set 30 | wuan
# Processing Record 346 of Set 30 | tura
# Processing Record 347 of Set 30 | le port
# Processing Record 348 of Set 30 | srivardhan
# Processing Record 349 of Set 30 | flin flon
# Processing Record 350 of Set 30 | corrales
# Processing Record 351 of Set 30 | los llanos de aridane
# Processing Record 352 of Set 30 | petropavlovsk-kamchatskiy
# Processing Record 353 of Set 30 | egvekinot
# Processing Record 354 of Set 30 | lebu
# Processing Record 355 of Set 30 | axim
# Processing Record 356 of Set 30 | nelson bay
# Processing Record 357 of Set 30 | camacha
# city(lolua) not found
# Processing Record 359 of Set 31 | innisfail
# Processing Record 360 of Set 31 | eskilstuna
# city(marcona) not found
# Processing Record 362 of Set 32 | saskylakh
# city(karmana) not found
# Processing Record 364 of Set 33 | kassala
# Processing Record 365 of Set 33 | vyskov
# Processing Record 366 of Set 33 | perth
# Processing Record 367 of Set 33 | stuttgart
# Processing Record 368 of Set 33 | pundaguitan
# Processing Record 369 of Set 33 | zambezi
# Processing Record 370 of Set 33 | atherton
# Processing Record 371 of Set 33 | san policarpo
# Processing Record 372 of Set 33 | byron bay
# Processing Record 373 of Set 33 | moose factory
# Processing Record 374 of Set 33 | necochea
# Processing Record 375 of Set 33 | floriano
# Processing Record 376 of Set 33 | hyderabad
# Processing Record 377 of Set 33 | bani walid
# Processing Record 378 of Set 33 | humboldt
# Processing Record 379 of Set 33 | ambovombe
# Processing Record 380 of Set 33 | port moresby
# Processing Record 381 of Set 33 | hit
# Processing Record 382 of Set 33 | micomeseng
# Processing Record 383 of Set 33 | eydhafushi
# Processing Record 384 of Set 33 | mocuba
# Processing Record 385 of Set 33 | samarai
# Processing Record 386 of Set 33 | westport
# Processing Record 387 of Set 33 | soria
# Processing Record 388 of Set 33 | vila velha
# Processing Record 389 of Set 33 | emba
# Processing Record 390 of Set 33 | lima
# Processing Record 391 of Set 33 | te anau
# Processing Record 392 of Set 33 | hope
# Processing Record 393 of Set 33 | xichang
# city(halalo) not found
# Processing Record 395 of Set 34 | maryville
# Processing Record 396 of Set 34 | saint-louis
# Processing Record 397 of Set 34 | saint-ambroise
# city(kuche) not found
# Processing Record 399 of Set 35 | ondjiva
# Processing Record 400 of Set 35 | taunggyi
# Processing Record 401 of Set 35 | inongo
# Processing Record 402 of Set 35 | mayo
# Processing Record 403 of Set 35 | tessalit
# Processing Record 404 of Set 35 | wisconsin rapids
# Processing Record 405 of Set 35 | labuhan
# city(fevralsk) not found
# Processing Record 407 of Set 36 | naze
# Processing Record 408 of Set 36 | kalat
# Processing Record 409 of Set 36 | pinega
# Processing Record 410 of Set 36 | sokolovyy
# Processing Record 411 of Set 36 | richards bay
# city(ijaki) not found
# Processing Record 413 of Set 37 | cockburn town
# Processing Record 414 of Set 37 | katherine
# Processing Record 415 of Set 37 | oviedo
# Processing Record 416 of Set 37 | adrar
# Processing Record 417 of Set 37 | yumen
# Processing Record 418 of Set 37 | margate
# Processing Record 419 of Set 37 | hammerfest
# Processing Record 420 of Set 37 | zhaotong
# Processing Record 421 of Set 37 | kangaba
# Processing Record 422 of Set 37 | dukat
# Processing Record 423 of Set 37 | khasan
# Processing Record 424 of Set 37 | whitehorse
# Processing Record 425 of Set 37 | constantine
# Processing Record 426 of Set 37 | bisira
# Processing Record 427 of Set 37 | kimbe
# Processing Record 428 of Set 37 | svetlogorsk
# Processing Record 429 of Set 37 | naryan-mar
# Processing Record 430 of Set 37 | chifeng
# Processing Record 431 of Set 37 | dapaong
# Processing Record 432 of Set 37 | jumla
# Processing Record 433 of Set 37 | juneau
# Processing Record 434 of Set 37 | vacha
# Processing Record 435 of Set 37 | vao
# Processing Record 436 of Set 37 | mitsamiouli
# Processing Record 437 of Set 37 | zharkent
# city(longlac) not found
# city(petrolandia) not found
# Processing Record 440 of Set 39 | hobbs
# Processing Record 441 of Set 39 | clyde river
# Processing Record 442 of Set 39 | nador
# Processing Record 443 of Set 39 | huallanca
# Processing Record 444 of Set 39 | port lincoln
# Processing Record 445 of Set 39 | saint-francois
# city(hunza) not found
# Processing Record 447 of Set 40 | savannah bight
# city(blonduos) not found
# Processing Record 449 of Set 41 | itamaraju
# Processing Record 450 of Set 41 | avera
# Processing Record 451 of Set 41 | tarko-sale
# Processing Record 452 of Set 41 | uray
# Processing Record 453 of Set 41 | tautira
# city(qandahar) not found
# Processing Record 455 of Set 42 | marienburg
# Processing Record 456 of Set 42 | diffa
# Processing Record 457 of Set 42 | stejaru
# Processing Record 458 of Set 42 | walvis bay
# city(ruatoria) not found
# Processing Record 460 of Set 43 | korla
# Processing Record 461 of Set 43 | severo-yeniseyskiy
# Processing Record 462 of Set 43 | varhaug
# Processing Record 463 of Set 43 | ranong
# Processing Record 464 of Set 43 | tatawin
# Processing Record 465 of Set 43 | kafanchan
# Processing Record 466 of Set 43 | dicabisagan
# Processing Record 467 of Set 43 | bay roberts
# Processing Record 468 of Set 43 | capoterra
# Processing Record 469 of Set 43 | shizuishan
# Processing Record 470 of Set 43 | mumbwa
# Processing Record 471 of Set 43 | sinegorye
# Processing Record 472 of Set 43 | mastic beach
# Processing Record 473 of Set 43 | chapais
# Processing Record 474 of Set 43 | yefremov
# Processing Record 475 of Set 43 | daru
# Processing Record 476 of Set 43 | terney
# Processing Record 477 of Set 43 | along
# Processing Record 478 of Set 43 | verkhoyansk
# Processing Record 479 of Set 43 | sapa
# Processing Record 480 of Set 43 | carballo
# Processing Record 481 of Set 43 | jiuquan
# Processing Record 482 of Set 43 | sitka
# Processing Record 483 of Set 43 | nantucket
# Processing Record 484 of Set 43 | evensk
# city(utiroa) not found
# Processing Record 486 of Set 44 | college
# Processing Record 487 of Set 44 | mayor pablo lagerenza
# Processing Record 488 of Set 44 | birjand
# Processing Record 489 of Set 44 | waipawa
# Processing Record 490 of Set 44 | wajima
# Processing Record 491 of Set 44 | savonlinna
# Processing Record 492 of Set 44 | talnakh
# Processing Record 493 of Set 44 | liverpool
# Processing Record 494 of Set 44 | boulsa
# Processing Record 495 of Set 44 | rock sound
# city(aflu) not found
# city(grand centre) not found
# Processing Record 498 of Set 46 | resavica
# Processing Record 499 of Set 46 | mustang
# Processing Record 500 of Set 46 | waingapu
# Processing Record 501 of Set 46 | jackson
# Processing Record 502 of Set 46 | san rafael
# Processing Record 503 of Set 46 | quixada
# Processing Record 504 of Set 46 | vila real
# Processing Record 505 of Set 46 | aripuana
# Processing Record 506 of Set 46 | christchurch
# Processing Record 507 of Set 46 | khipro
# Processing Record 508 of Set 46 | port-gentil
# Processing Record 509 of Set 46 | saint-joseph
# Processing Record 510 of Set 46 | numan
# Processing Record 511 of Set 46 | davlekanovo
# Processing Record 512 of Set 46 | piranshahr
# Processing Record 513 of Set 46 | havelock
# Processing Record 514 of Set 46 | leshukonskoye
# Processing Record 515 of Set 46 | mount pleasant
# Processing Record 516 of Set 46 | pacifica
# Processing Record 517 of Set 46 | windsor
# Processing Record 518 of Set 46 | teya
# Processing Record 519 of Set 46 | antalaha
# Processing Record 520 of Set 46 | mezen
# Processing Record 521 of Set 46 | cabedelo
# Processing Record 522 of Set 46 | vostok
# Processing Record 523 of Set 46 | jaynagar-majilpur
# city(galiwinku) not found
# Processing Record 525 of Set 47 | norwich
# Processing Record 526 of Set 47 | maarianhamina
# Processing Record 527 of Set 47 | tazmalt
# Processing Record 528 of Set 47 | kovur
# Processing Record 529 of Set 47 | bosaso
# Processing Record 530 of Set 47 | acapulco
# Processing Record 531 of Set 47 | bowen
# Processing Record 532 of Set 47 | svetlyy
# Processing Record 533 of Set 47 | valdemarpils
# Processing Record 534 of Set 47 | gat
# Processing Record 535 of Set 47 | san cristobal
# Processing Record 536 of Set 47 | baoro
# Processing Record 537 of Set 47 | neiafu
# Processing Record 538 of Set 47 | apollonia
# Processing Record 539 of Set 47 | oxapampa
# Processing Record 540 of Set 47 | boende
# Processing Record 541 of Set 47 | roela
# Processing Record 542 of Set 47 | riyadh
# Processing Record 543 of Set 47 | ngunguru
# Processing Record 544 of Set 47 | mangrol
# Processing Record 545 of Set 47 | seoul
# Processing Record 546 of Set 47 | minot
# Processing Record 547 of Set 47 | kasba
# Processing Record 548 of Set 47 | ponta delgada
# Processing Record 549 of Set 47 | haines junction
# city(zhaocheng) not found
# Processing Record 551 of Set 48 | mutis
# Processing Record 552 of Set 48 | maracaju
# Processing Record 553 of Set 48 | fallon
# Processing Record 554 of Set 48 | vila franca do campo
# city(cheyur) not found
# Processing Record 556 of Set 49 | tullahoma
# Processing Record 557 of Set 49 | pacific grove
# Processing Record 558 of Set 49 | sarakhs
# Processing Record 559 of Set 49 | kokopo
# city(mendahara) not found
# Processing Record 561 of Set 50 | port hardy
# Processing Record 562 of Set 50 | zakopane
# Processing Record 563 of Set 50 | praya
# city(sataua) not found
# city(tabiauea) not found
# Processing Record 566 of Set 52 | pavilosta
# Processing Record 567 of Set 52 | lavumisa
# Processing Record 568 of Set 52 | broken hill
# Processing Record 569 of Set 52 | casa nova
# Processing Record 570 of Set 52 | ahuimanu
# Processing Record 571 of Set 52 | turkistan
# Processing Record 572 of Set 52 | apatity
# Processing Record 573 of Set 52 | pryazha
# Processing Record 574 of Set 52 | wucheng
# Processing Record 575 of Set 52 | yakeshi
# Processing Record 576 of Set 52 | prince george
# Processing Record 577 of Set 52 | burnie
# Processing Record 578 of Set 52 | coruripe
# Processing Record 579 of Set 52 | moree
# Processing Record 580 of Set 52 | broome
# Processing Record 581 of Set 52 | sisimiut
# Processing Record 582 of Set 52 | caravelas
# Processing Record 583 of Set 52 | turukhansk
# Processing Record 584 of Set 52 | toora-khem
# Processing Record 585 of Set 52 | boli
# Processing Record 586 of Set 52 | leshan
# Processing Record 587 of Set 52 | batouri

# %%
# Calculate number of cities found
found = len(cities)
not_found = len(not_located)
total_found = found - not_found
print(f'Cities were found {total_found}')

# %% [markdown]
# # Create Dataframe to store requests from those lists

# %%
#format the column of dates of the df
dates = []
for d in date:
    date_test = d
    date_conversion = time.gmtime(date_test)
    date_format = time.strftime('%m/%d/%Y',date_conversion)
    dates.append(date_format)
# dates

# %%
# dates

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "city": city_name,
    "cloudiness":cloudiness,
    "Country":country,
    "date":dates,
    "humid":humidity,
    "lat": lat,
    "lng":lon,
    "max_temp": max_temp,
    "wind_speed":wind_speed,
}

weather_data = pd.DataFrame(weather_dict)
weather_df = weather_data.rename(columns={
    "city":"City",
    "cloudiness":"Cloudiness",
    "date":"Date",
    "humid":"Humidity (%)",
    "lng":"Longitude",
    "max_temp":"Max Temperature",
    "wind_speed":"Wind Speed",
    "lat":"Longitude"
 })
weather_data.to_csv("output_data/cities.csv", index = False)
count_weather_data = weather_df.count()

# %%
weather_data.head()

# %% [markdown]
# # Create scatter plots

# %% [markdown]
# Latitude vs. Max Temperature

# %%
# Build a scatter plot for each data type
title_date = dates[0]
plt.scatter(weather_data["lat"], weather_data["max_temp"], marker = 'o',
           edgecolor='red', alpha=.7)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Temperature({title_date})")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(alpha=0.2)

#print graph to output
plt.savefig('output_data/latitude_MaxTemp.png')

# Show plot
# plt.show()

# %% [markdown]
# Latitude vs. Humidity

# %%
# Build a scatter plot for each data type
title_date = dates[0]
plt.scatter(weather_data["lat"], weather_data["humid"], 
            edgecolor='green', alpha=.7)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity({title_date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(alpha=0.2)

#print graph to output
plt.savefig('output_data/latitude_Humidity.png')

# Show plot
plt.show()

# %% [markdown]
# Latitude vs. Cloudiness

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["cloudiness"],
           edgecolor='blue', alpha=.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({title_date})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(alpha=0.2)

#print graph to output
plt.savefig('output_data/latitude_Cloudiness.png')

# Show plot
plt.show()

#print graph to output
plt.savefig('output_data/latitude_Cloudiness.png')

# %% [markdown]
# Latitude vs. Wind Speed

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["wind_speed"],
            edgecolor='black', alpha=.5)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({title_date})")
plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(alpha=0.2)

#print graph to output
plt.savefig('output_data/latitude_WindSpeed.png')

# Show plot
plt.show()

# %% [markdown]
# # Northern and Southern Hemisphere

# %%
# weather_data.head(3)

# %%
# Select data for northern and southern
# Use df.loc[df['column_name']=='condition'] to create criteria
# and put into new df
northern_df = weather_data.loc[weather_data["lat"]>=0]
southern_df = weather_data.loc[weather_data["lat"]<0]
# northern_df
# southern_df

# %% [markdown]
# # Linear Regression

# %% [markdown]
# Northern Hemisphere
# (Max Temperature vs Latitude)

# %%
# Use df.loc[:,'cloumns'] to select specific column
north_temp = northern_df.loc[:,'max_temp']
north_lat = northern_df.loc[:,'lat']
# north_temp
# north_lat

# Calculate the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat,north_temp)
print(f'The correlation factor is {round(rvalue,2)}')

# %%
plt.scatter(north_lat,north_temp)
plt.title(f'Northern Hemisphere\n Max Temp vs. Latitude Linear Regression\n ({dates[0]})')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(alpha=0.2)

regress = north_lat * slope + intercept
# regress

# Calculate y equation
line_equation = print(f"y = {round(slope, 2)} x + {round(intercept,2)}")

plt.plot(north_lat, regress, 'r-')
plt.savefig("output_data/northLat_maxTemp.png")

# %% [markdown]
# Sothern Hemisphere (Max Temperature vs Latitude)

# %%
# Use df.loc[:,'cloumns'] to select specific column
south_temp = southern_df.loc[:,'max_temp']
south_lat = southern_df.loc[:,'lat']
# south_temp
# south_lat

# Calculate the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat,south_temp)
print(f'The correlation factor is {round(rvalue,2)}')

# %%
plt.scatter(south_lat,south_temp)
plt.title(f'Southern Hemisphere\n Max Temp vs. Latitude Linear Regression\n ({dates[0]})')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(alpha=0.2)

regress = south_lat * slope + intercept
# regress

# Calculate y equation
line_equation = print(f"y = {round(slope, 2)} x + {round(intercept,2)}")

plt.plot(south_lat, regress, 'r-')
plt.savefig("output_data/southLat_maxTemp.png")

# %% [markdown]
# Northern Hemisphere - Humidity (%) vs. Latitude

# %%
north_humid = northern_df.loc[:,'humid']
north_lat = northern_df.loc[:,'lat']

# Calculate the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat,north_humid)
print(f'The correlation factor is {round(rvalue,2)}')

# %%
plt.scatter(north_lat,north_humid)
plt.title(f'Northern Hemisphere\n Humidity (%) vs. Latitude Linear Regression\n ({dates[0]})')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(alpha=0.2)

regress = north_lat * slope + intercept
# regress

# Calculate y equation
line_equation = print(f"y = {round(slope, 2)} x + {round(intercept,2)}")

plt.plot(north_lat, regress, 'r-')
plt.savefig("output_data/northLat_humidity.png")

# %% [markdown]
# Southern Hemisphere - Humidity (%) vs. Latitude

# %%
south_temp = southern_df.loc[:,'humid']
south_lat = southern_df.loc[:,'lat']

# Calculate the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat,south_temp)
print(f'The correlation factor is {round(rvalue,2)}')

# %%
plt.scatter(south_lat,south_temp)
plt.title(f'Southern Hemisphere\n Humidty (%) vs. Latitude Linear Regression\n ({dates[0]})')
plt.xlabel('Latitude')
plt.ylabel('Humidty (%)')
plt.grid(alpha=0.2)

regress = south_lat * slope + intercept
# regress

# Calculate y equation
line_equation = print(f"y = {round(slope, 2)} x + {round(intercept,2)}")

plt.plot(south_lat, regress, 'r-')
plt.savefig("output_data/southLat_humidity.png")

# %% [markdown]
# Northern Hemisphere - Cloudiness vs. Latitude

# %%
north_humid = northern_df.loc[:,'cloudiness']
north_lat = northern_df.loc[:,'lat']

# Calculate the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat,north_humid)
print(f'The correlation factor is {round(rvalue,2)}')

# %%
plt.scatter(north_lat,north_humid)
plt.title(f'Northern Hemisphere\n Cloudiness vs. Latitude Linear Regression\n ({dates[0]})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(alpha=0.2)

regress = north_lat * slope + intercept
# regress

# Calculate y equation
line_equation = print(f"y = {round(slope, 2)} x + {round(intercept,2)}")

plt.plot(north_lat, regress, 'r-')
plt.savefig("output_data/northLat_humidity.png")

# %% [markdown]
# Southern Hemisphere - Cloudiness vs. Latitude

# %%
south_temp = southern_df.loc[:,'cloudiness']
south_lat = southern_df.loc[:,'lat']

# Calculate the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat,south_temp)
print(f'The correlation factor is {round(rvalue,2)}')

# %%
plt.scatter(south_lat,south_temp)
plt.title(f'Southern Hemisphere\n Cloudiness vs. Latitude Linear Regression\n ({dates[0]})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(alpha=0.2)

regress = south_lat * slope + intercept
# regress

# Calculate y equation
line_equation = print(f"y = {round(slope, 2)} x + {round(intercept,2)}")

plt.plot(south_lat, regress, 'r-')
plt.savefig("output_data/southLat_humidity.png")

# %% [markdown]
# Northern Hemisphere - Wind Speed (MPH) vs. Latitude

# %%
north_humid = northern_df.loc[:,'wind_speed']
north_lat = northern_df.loc[:,'lat']

# Calculate the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat,north_humid)
print(f'The correlation factor is {round(rvalue,2)}')

# %%
plt.scatter(north_lat,north_humid)
plt.title(f'Northern Hemisphere\n Wind Speed (MPH) vs. Latitude Linear Regression\n ({dates[0]})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.grid(alpha=0.2)

regress = north_lat * slope + intercept
# regress

# Calculate y equation
line_equation = print(f"y = {round(slope, 2)} x + {round(intercept,2)}")

plt.plot(north_lat, regress, 'r-')
plt.savefig("output_data/northLat_humidity.png")

# %% [markdown]
# Southern Hemisphere - Wind Speed (MPH) vs. Latitude

# %%
south_temp = southern_df.loc[:,'wind_speed']
south_lat = southern_df.loc[:,'lat']

# Calculate the linear regression using scipy.stats library
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat,south_temp)
print(f'The correlation factor is {round(rvalue,2)}')

# %%
plt.scatter(south_lat,south_temp)
plt.title(f'Southern Hemisphere\n Wind Speed (MPH) vs. Latitude Linear Regression\n ({dates[0]})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.grid(alpha=0.2)

regress = south_lat * slope + intercept
# regress

# Calculate y equation
line_equation = print(f"y = {round(slope, 2)} x + {round(intercept,2)}")

plt.plot(south_lat, regress, 'r-')
plt.savefig("output_data/southLat_humidity.png")

# %% [markdown]
# # Analysis
